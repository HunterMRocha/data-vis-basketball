# %%
import pandas as pd
import requests
from datetime import datetime

# %%
df1 = pd.read_csv('curry.csv')
df1.head()
# Out:
#            GRID_TYPE     GAME_ID GAME_EVENT_ID PLAYER_ID    PLAYER_NAME  \
# 0  Shot Chart Detail  0020900015             4    201939  Stephen Curry
# 1  Shot Chart Detail  0020900015            17    201939  Stephen Curry
# 2  Shot Chart Detail  0020900015            53    201939  Stephen Curry
# 3  Shot Chart Detail  0020900015           141    201939  Stephen Curry
# 4  Shot Chart Detail  0020900015           249    201939  Stephen Curry
#
#       TEAM_ID              TEAM_NAME PERIOD MINUTES_REMAINING  \
# 0  1610612744  Golden State Warriors      1                11
# 1  1610612744  Golden State Warriors      1                 9
# 2  1610612744  Golden State Warriors      1                 6
# 3  1610612744  Golden State Warriors      2                 9
# 4  1610612744  Golden State Warriors      2                 2
#
#   SECONDS_REMAINING  ...         SHOT_ZONE_AREA SHOT_ZONE_RANGE SHOT_DISTANCE  \
# ...

# %%
remove_me = ["GRID_TYPE", 'GAME_ID', 'GAME_EVENT_ID', 'PLAYER_ID','PLAYER_NAME','TEAM_ID', 'SHOT_ATTEMPTED_FLAG','TEAM_NAME','SHOT_TYPE','EVENT_TYPE']
df1.drop(remove_me, axis=1, inplace=True)

# %%
df1.head()
# Out:
#   PERIOD MINUTES_REMAINING SECONDS_REMAINING          ACTION_TYPE  \
# 0      1                11                25            Jump Shot
# 1      1                 9                31  Step Back Jump shot
# 2      1                 6                 2            Jump Shot
# 3      2                 9                49            Jump Shot
# 4      2                 2                19            Jump Shot
#
#          SHOT_ZONE_BASIC         SHOT_ZONE_AREA SHOT_ZONE_RANGE SHOT_DISTANCE  \
# 0      Above the Break 3  Right Side Center(RC)         24+ ft.            26
# 1              Mid-Range   Left Side Center(LC)       16-24 ft.            18
# 2  In The Paint (Non-RA)              Center(C)        8-16 ft.            14
# 3              Mid-Range           Left Side(L)       16-24 ft.            19
# 4              Mid-Range   Left Side Center(LC)       16-24 ft.            16
#
#   LOC_X LOC_Y SHOT_MADE_FLAG GAME_DATE  HTM  VTM
# 0    99   249              0  20091028  GSW  HOU
# ...

# %%
new_names = {'PERIOD':'period', 
            'MINUTES_REMAINING':'minutes_remaining',
             'SECONDS_REMAINING':'seconds_remaning',
             'ACTION_TYPE':'action_type',
             'SHOT_ZONE_BASIC':'shot_zone_basic',
             'SHOT_ZONE_AREA':'shot_zone_area',
             'SHOT_ZONE_RANGE':'shot_zone_range',
             'SHOT_DISTANCE':'shot_distance',
             'LOC_X':'loc_x',
             'LOC_Y':'loc_y',
             'SHOT_MADE_FLAG': 'shot_made_flag',
             'GAME_DATE':'game_date',
             'VTM':'opponent'
            }
df1 = df1.rename(columns=new_names)
df1.head()
# Out:
#   period minutes_remaining seconds_remaning          action_type  \
# 0      1                11               25            Jump Shot
# 1      1                 9               31  Step Back Jump shot
# 2      1                 6                2            Jump Shot
# 3      2                 9               49            Jump Shot
# 4      2                 2               19            Jump Shot
#
#          shot_zone_basic         shot_zone_area shot_zone_range shot_distance  \
# 0      Above the Break 3  Right Side Center(RC)         24+ ft.            26
# 1              Mid-Range   Left Side Center(LC)       16-24 ft.            18
# 2  In The Paint (Non-RA)              Center(C)        8-16 ft.            14
# 3              Mid-Range           Left Side(L)       16-24 ft.            19
# 4              Mid-Range   Left Side Center(LC)       16-24 ft.            16
#
#   loc_x loc_y shot_made_flag game_date  HTM opponent
# ...

# %%
df2 = pd.read_csv('kobe.csv')
df2.head()
# Out:
#    period  minutes_remaining  seconds_remaining action_type  \
# 0       1                  0                 42   Jump Shot
# 1       2                 10                  8   Jump Shot
# 2       2                  8                 37   Jump Shot
# 3       2                  6                 34   Jump Shot
# 4       2                  5                 27   Jump Shot
#
#          shot_zone_basic        shot_zone_area  shot_zone_range  \
# 0              Mid-Range  Left Side Center(LC)        16-24 ft.
# 1              Mid-Range  Left Side Center(LC)        16-24 ft.
# 2              Mid-Range  Left Side Center(LC)        16-24 ft.
# 3        Restricted Area             Center(C)  Less Than 8 ft.
# 4  In The Paint (Non-RA)             Center(C)         8-16 ft.
#
#    shot_distance  loc_x  loc_y  shot_made_flag  game_date   season  playoffs  \
# 0             18   -140    116               0   19961103  1996-97         0
# ...
